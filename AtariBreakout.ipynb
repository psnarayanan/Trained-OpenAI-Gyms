# %%
import gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os
print("Completed Import")
# Out:
# Completed Import

# %%
#download http://www.atarimania.com/roms/Roms.rar
#!pip install atari_py
# !python -m atari_py.import_roms .\ROMS\ROMS
# Out:
# copying adventure.bin from .\ROMS\ROMS\Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\adventure.bin
# copying air_raid.bin from .\ROMS\ROMS\Air Raid (Men-A-Vision) (PAL) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\air_raid.bin
# copying alien.bin from .\ROMS\ROMS\Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\alien.bin
# copying amidar.bin from .\ROMS\ROMS\Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\amidar.bin
# copying assault.bin from .\ROMS\ROMS\Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\assault.bin
# copying asterix.bin from .\ROMS\ROMS\Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\asterix.bin
# copying asteroids.bin from .\ROMS\ROMS\Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\asteroids.bin
# copying atlantis.bin from .\ROMS\ROMS\Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\atlantis.bin
# copying bank_heist.bin from .\ROMS\ROMS\Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\bank_heist.bin
# copying battle_zone.bin from .\ROMS\ROMS\Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\battle_zone.bin
# copying beam_rider.bin from .\ROMS\ROMS\Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\beam_rider.bin
# copying berzerk.bin from .\ROMS\ROMS\Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\berzerk.bin
# copying bowling.bin from .\ROMS\ROMS\Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\bowling.bin
# copying boxing.bin from .\ROMS\ROMS\Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\boxing.bin
# copying breakout.bin from .\ROMS\ROMS\Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\breakout.bin
# copying carnival.bin from .\ROMS\ROMS\Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\carnival.bin
# copying centipede.bin from .\ROMS\ROMS\Centipede (1983) (Atari - GCC) (CX2676) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\centipede.bin
# copying chopper_command.bin from .\ROMS\ROMS\Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\chopper_command.bin
# copying crazy_climber.bin from .\ROMS\ROMS\Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\crazy_climber.bin
# copying defender.bin from .\ROMS\ROMS\Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\defender.bin
# copying demon_attack.bin from .\ROMS\ROMS\Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\demon_attack.bin
# copying donkey_kong.bin from .\ROMS\ROMS\Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\donkey_kong.bin
# copying double_dunk.bin from .\ROMS\ROMS\Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\double_dunk.bin
# copying elevator_action.bin from .\ROMS\ROMS\Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\elevator_action.bin
# copying enduro.bin from .\ROMS\ROMS\Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\enduro.bin
# copying fishing_derby.bin from .\ROMS\ROMS\Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\fishing_derby.bin
# copying freeway.bin from .\ROMS\ROMS\Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\freeway.bin
# copying frogger.bin from .\ROMS\ROMS\Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\frogger.bin
# copying frostbite.bin from .\ROMS\ROMS\Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\frostbite.bin
# copying galaxian.bin from .\ROMS\ROMS\Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\galaxian.bin
# copying gopher.bin from .\ROMS\ROMS\Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\gopher.bin
# copying gravitar.bin from .\ROMS\ROMS\Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\gravitar.bin
# copying hero.bin from .\ROMS\ROMS\H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\hero.bin
# copying ice_hockey.bin from .\ROMS\ROMS\Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\ice_hockey.bin
# copying jamesbond.bin from .\ROMS\ROMS\James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\jamesbond.bin
# copying journey_escape.bin from .\ROMS\ROMS\Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\journey_escape.bin
# copying kaboom.bin from .\ROMS\ROMS\Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\kaboom.bin
# copying kangaroo.bin from .\ROMS\ROMS\Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\kangaroo.bin
# copying keystone_kapers.bin from .\ROMS\ROMS\Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\keystone_kapers.bin
# copying king_kong.bin from .\ROMS\ROMS\King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\king_kong.bin
# copying koolaid.bin from .\ROMS\ROMS\Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\koolaid.bin
# copying krull.bin from .\ROMS\ROMS\Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\krull.bin
# copying kung_fu_master.bin from .\ROMS\ROMS\Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\kung_fu_master.bin
# copying laser_gates.bin from .\ROMS\ROMS\Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\laser_gates.bin
# copying lost_luggage.bin from .\ROMS\ROMS\Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\lost_luggage.bin
# copying montezuma_revenge.bin from .\ROMS\ROMS\Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\montezuma_revenge.bin
# copying mr_do.bin from .\ROMS\ROMS\Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\mr_do.bin
# copying ms_pacman.bin from .\ROMS\ROMS\Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\ms_pacman.bin
# copying name_this_game.bin from .\ROMS\ROMS\Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\name_this_game.bin
# copying pacman.bin from .\ROMS\ROMS\Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\pacman.bin
# copying phoenix.bin from .\ROMS\ROMS\Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\phoenix.bin
# copying video_pinball.bin from .\ROMS\ROMS\Pinball (AKA Video Pinball) (Zellers).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\video_pinball.bin
# copying pitfall.bin from .\ROMS\ROMS\Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\pitfall.bin
# copying pooyan.bin from .\ROMS\ROMS\Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\pooyan.bin
# copying private_eye.bin from .\ROMS\ROMS\Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\private_eye.bin
# copying qbert.bin from .\ROMS\ROMS\Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\qbert.bin
# copying riverraid.bin from .\ROMS\ROMS\River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\riverraid.bin
# copying road_runner.bin from patched version of .\ROMS\ROMS\Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\road_runner.bin
# copying robotank.bin from .\ROMS\ROMS\Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\robotank.bin
# copying seaquest.bin from .\ROMS\ROMS\Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\seaquest.bin
# copying sir_lancelot.bin from .\ROMS\ROMS\Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\sir_lancelot.bin
# copying skiing.bin from .\ROMS\ROMS\Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\skiing.bin
# copying solaris.bin from .\ROMS\ROMS\Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\solaris.bin
# copying space_invaders.bin from .\ROMS\ROMS\Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\space_invaders.bin
# copying star_gunner.bin from .\ROMS\ROMS\Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\star_gunner.bin
# copying surround.bin from .\ROMS\ROMS\Surround (32 in 1) (Bit Corporation) (R320).bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\surround.bin
# copying tennis.bin from .\ROMS\ROMS\Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\tennis.bin
# copying time_pilot.bin from .\ROMS\ROMS\Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\time_pilot.bin
# copying trondead.bin from .\ROMS\ROMS\TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\trondead.bin
# copying tutankham.bin from .\ROMS\ROMS\Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\tutankham.bin
# copying up_n_down.bin from .\ROMS\ROMS\Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\up_n_down.bin
# copying venture.bin from .\ROMS\ROMS\Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\venture.bin
# copying pong.bin from .\ROMS\ROMS\Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\pong.bin
# copying wizard_of_wor.bin from .\ROMS\ROMS\Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\wizard_of_wor.bin
# copying yars_revenge.bin from .\ROMS\ROMS\Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\yars_revenge.bin
# copying zaxxon.bin from .\ROMS\ROMS\Zaxxon (1983) (Coleco) (2454) ~.bin to C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\atari_py\atari_roms\zaxxon.bin

# %%
environment_name = "Breakout-v0"
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, info = env.step(action)
        score+=reward
    
    print("Episode:{} Score:{}".format(episode, score))
env.close()
# Out:
# Episode:1 Score:2.0
# Episode:2 Score:1.0
# Episode:3 Score:2.0
# Episode:4 Score:4.0
# Episode:5 Score:2.0

# %%
env = make_atari_env(environment_name, n_envs=4, seed=0)
env = VecFrameStack(env, n_stack=4)
log_path = os.path.join("Training", "Logs")

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\A2C_5
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 276      |
# |    ep_rew_mean        | 1.41     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 100      |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.27     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.221   |
# |    value_loss         | 0.0448   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 281      |
# |    ep_rew_mean        | 1.54     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 200      |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.725    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0269  |
# |    value_loss         | 0.0619   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 285      |
# |    ep_rew_mean        | 1.63     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 300      |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.59     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.196   |
# |    value_loss         | 0.0618   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.84     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 400      |
# |    time_elapsed       | 202      |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.8      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.239    |
# |    value_loss         | 0.133    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 319      |
# |    ep_rew_mean        | 2.23     |
# | time/                 |          |
# |    fps                | 40       |
# |    iterations         | 500      |
# |    time_elapsed       | 247      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0119  |
# |    value_loss         | 0.0125   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 326      |
# |    ep_rew_mean        | 2.39     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 600      |
# |    time_elapsed       | 301      |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.764    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.158    |
# |    value_loss         | 0.085    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 2.46     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 700      |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.731   |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0686  |
# |    value_loss         | 0.0914   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 321      |
# |    ep_rew_mean        | 2.32     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 800      |
# |    time_elapsed       | 406      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0413  |
# |    value_loss         | 0.0121   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 322      |
# |    ep_rew_mean        | 2.33     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 900      |
# |    time_elapsed       | 454      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0947  |
# |    value_loss         | 0.0277   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 340      |
# |    ep_rew_mean        | 2.7      |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 1000     |
# |    time_elapsed       | 509      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0396  |
# |    value_loss         | 0.00726  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 337      |
# |    ep_rew_mean        | 2.65     |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 1100     |
# |    time_elapsed       | 568      |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | 0.926    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.167   |
# |    value_loss         | 0.0685   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 352      |
# |    ep_rew_mean        | 3.02     |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 1200     |
# |    time_elapsed       | 629      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.747    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0385  |
# |    value_loss         | 0.0812   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 349      |
# |    ep_rew_mean        | 2.98     |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 1300     |
# |    time_elapsed       | 682      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.7     |
# |    explained_variance | -0.915   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0256  |
# |    value_loss         | 0.00434  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 320      |
# |    ep_rew_mean        | 2.52     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 1400     |
# |    time_elapsed       | 744      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.161   |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.00774  |
# |    value_loss         | 0.00722  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 283      |
# |    ep_rew_mean        | 1.87     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 1500     |
# |    time_elapsed       | 810      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.975   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.141   |
# |    value_loss         | 0.0979   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 309      |
# |    ep_rew_mean        | 2.44     |
# | time/                 |          |
# |    fps                | 36       |
# |    iterations         | 1600     |
# |    time_elapsed       | 871      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.469   |
# |    explained_variance | 0.935    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0346  |
# |    value_loss         | 0.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 2.91     |
# | time/                 |          |
# |    fps                | 36       |
# |    iterations         | 1700     |
# |    time_elapsed       | 929      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.828   |
# |    explained_variance | 0.799    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.102   |
# |    value_loss         | 0.109    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 375      |
# |    ep_rew_mean        | 3.78     |
# | time/                 |          |
# |    fps                | 36       |
# |    iterations         | 1800     |
# |    time_elapsed       | 983      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.206   |
# |    explained_variance | 0.932    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0983  |
# |    value_loss         | 0.178    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 405      |
# |    ep_rew_mean        | 4.35     |
# | time/                 |          |
# |    fps                | 36       |
# |    iterations         | 1900     |
# |    time_elapsed       | 1043     |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.303   |
# |    explained_variance | 0.899    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.003    |
# |    value_loss         | 0.0743   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 412       |
# |    ep_rew_mean        | 4.48      |
# | time/                 |           |
# |    fps                | 36        |
# |    iterations         | 2000      |
# |    time_elapsed       | 1093      |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.0885   |
# |    explained_variance | 0.957     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000999 |
# |    value_loss         | 0.0286    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 435      |
# |    ep_rew_mean        | 4.92     |
# | time/                 |          |
# |    fps                | 36       |
# |    iterations         | 2100     |
# |    time_elapsed       | 1137     |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.107   |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.00569  |
# |    value_loss         | 0.0256   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 434      |
# |    ep_rew_mean        | 4.9      |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2200     |
# |    time_elapsed       | 1187     |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0186   |
# |    value_loss         | 0.0561   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 443      |
# |    ep_rew_mean        | 5.13     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2300     |
# |    time_elapsed       | 1236     |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.343   |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0249   |
# |    value_loss         | 0.0544   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 435      |
# |    ep_rew_mean        | 4.96     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2400     |
# |    time_elapsed       | 1282     |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.19    |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.115   |
# |    value_loss         | 0.0382   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 444      |
# |    ep_rew_mean        | 5.17     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2500     |
# |    time_elapsed       | 1331     |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.416   |
# |    explained_variance | 0.851    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.142   |
# |    value_loss         | 0.0777   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 449      |
# |    ep_rew_mean        | 5.19     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2600     |
# |    time_elapsed       | 1381     |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.484   |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0752  |
# |    value_loss         | 0.0602   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 425      |
# |    ep_rew_mean        | 4.64     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2700     |
# |    time_elapsed       | 1436     |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.104   |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.00301 |
# |    value_loss         | 0.00343  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 421      |
# |    ep_rew_mean        | 4.46     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2800     |
# |    time_elapsed       | 1485     |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.247   |
# |    explained_variance | 0.908    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.000259 |
# |    value_loss         | 0.049    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 418      |
# |    ep_rew_mean        | 4.38     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 2900     |
# |    time_elapsed       | 1533     |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.157   |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.00172 |
# |    value_loss         | 0.0226   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 413      |
# |    ep_rew_mean        | 4.32     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 3000     |
# |    time_elapsed       | 1589     |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.35    |
# |    explained_variance | 0.429    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0148   |
# |    value_loss         | 0.155    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 417      |
# |    ep_rew_mean        | 4.45     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 3100     |
# |    time_elapsed       | 1647     |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | 0.846    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00336  |
# |    value_loss         | 0.0808   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 5.11     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 3200     |
# |    time_elapsed       | 1689     |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.272   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0171  |
# |    value_loss         | 0.0521   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 457      |
# |    ep_rew_mean        | 5.36     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 3300     |
# |    time_elapsed       | 1745     |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.0807  |
# |    explained_variance | -0.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0191   |
# |    value_loss         | 0.397    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 458      |
# |    ep_rew_mean        | 5.47     |
# | time/                 |          |
# |    fps                | 37       |
# |    iterations         | 3400     |
# |    time_elapsed       | 1794     |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0277   |
# |    value_loss         | 0.0902   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 457       |
# |    ep_rew_mean        | 5.52      |
# | time/                 |           |
# |    fps                | 38        |
# |    iterations         | 3500      |
# |    time_elapsed       | 1840      |
# |    total_timesteps    | 70000     |
# | train/                |           |
# |    entropy_loss       | -0.0255   |
# |    explained_variance | -0.116    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -9.04e-05 |
# |    value_loss         | 0.216     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 458      |
# |    ep_rew_mean        | 5.53     |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 3600     |
# |    time_elapsed       | 1883     |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.202   |
# |    explained_variance | 0.702    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00148 |
# |    value_loss         | 0.137    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 455      |
# |    ep_rew_mean        | 5.45     |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 3700     |
# |    time_elapsed       | 1927     |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.302   |
# |    explained_variance | 0.706    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.117    |
# |    value_loss         | 0.184    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 460      |
# |    ep_rew_mean        | 5.58     |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 3800     |
# |    time_elapsed       | 1965     |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | 0.213    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0443   |
# |    value_loss         | 0.293    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 473      |
# |    ep_rew_mean        | 5.8      |
# | time/                 |          |
# |    fps                | 38       |
# |    iterations         | 3900     |
# |    time_elapsed       | 2003     |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.35    |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0185  |
# |    value_loss         | 0.0451   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 479      |
# |    ep_rew_mean        | 5.98     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 4000     |
# |    time_elapsed       | 2041     |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.328   |
# |    explained_variance | 0.794    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.13    |
# |    value_loss         | 0.125    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 490      |
# |    ep_rew_mean        | 6.2      |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 4100     |
# |    time_elapsed       | 2083     |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.364   |
# |    explained_variance | 0.867    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0135  |
# |    value_loss         | 0.037    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 498      |
# |    ep_rew_mean        | 6.34     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 4200     |
# |    time_elapsed       | 2124     |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.433   |
# |    explained_variance | 0.908    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0881  |
# |    value_loss         | 0.0568   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 516      |
# |    ep_rew_mean        | 6.71     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 4300     |
# |    time_elapsed       | 2168     |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.291   |
# |    explained_variance | 0.686    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.045   |
# |    value_loss         | 0.0594   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 504      |
# |    ep_rew_mean        | 6.48     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 4400     |
# |    time_elapsed       | 2212     |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.834   |
# |    explained_variance | 0.738    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.265   |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 487      |
# |    ep_rew_mean        | 6.02     |
# | time/                 |          |
# |    fps                | 39       |
# |    iterations         | 4500     |
# |    time_elapsed       | 2255     |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | -0.221   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.384   |
# |    value_loss         | 0.376    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 485      |
# |    ep_rew_mean        | 5.98     |
# | time/                 |          |
# |    fps                | 40       |
# |    iterations         | 4600     |
# |    time_elapsed       | 2298     |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.235   |
# |    explained_variance | 0.811    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0351   |
# |    value_loss         | 0.156    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 486      |
# |    ep_rew_mean        | 5.97     |
# | time/                 |          |
# |    fps                | 40       |
# |    iterations         | 4700     |
# |    time_elapsed       | 2340     |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.0896  |
# |    explained_variance | -1.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.00265 |
# |    value_loss         | 0.188    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 475      |
# |    ep_rew_mean        | 5.74     |
# | time/                 |          |
# |    fps                | 40       |
# |    iterations         | 4800     |
# |    time_elapsed       | 2384     |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.136   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.00108  |
# |    value_loss         | 0.0548   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 475      |
# |    ep_rew_mean        | 5.63     |
# | time/                 |          |
# |    fps                | 40       |
# |    iterations         | 4900     |
# |    time_elapsed       | 2426     |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.12    |
# |    explained_variance | 0.749    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00343  |
# |    value_loss         | 0.202    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 488      |
# |    ep_rew_mean        | 5.9      |
# | time/                 |          |
# |    fps                | 40       |
# |    iterations         | 5000     |
# |    time_elapsed       | 2470     |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.242   |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0222   |
# |    value_loss         | 0.0452   |
# ------------------------------------

# %%
a2c_path = os.path.join("Training", "Saved Models", "A2C_Breakout_Model")
model.save(a2c_path)

# %%
del model
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env = make_atari_env(environment_name, n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
evaluate_policy(model, env, n_eval_episodes=50, render=True)
env.close()

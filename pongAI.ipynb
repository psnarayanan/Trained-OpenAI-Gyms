# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "Pong-v0"
env = gym.make(environment_name)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
        
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
         
    print("Episode:{} Score:{}".format(episode, score))
env.close()
# Out:
# C:\Users\buzzp\AppData\Local\Programs\Python\Python310\lib\site-packages\pyglet\image\codecs\wic.py:434: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# Episode:1 Score:-21.0
# Episode:2 Score:-21.0
# Episode:3 Score:-21.0
# Episode:4 Score:-19.0
# Episode:5 Score:-19.0
# Episode:6 Score:-21.0
# Episode:7 Score:-21.0
# Episode:8 Score:-21.0
# Episode:9 Score:-21.0
# Episode:10 Score:-19.0

# %%
log_path = os.path.join("Training", "Logs")

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=50000)
# Out:
# Logging to Training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 52   |
# |    iterations      | 1    |
# |    time_elapsed    | 39   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 2           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016890194 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0343      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 0.0898      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 3           |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015412782 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0261      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 0.0891      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 4           |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013129477 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.029       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 0.0917      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 5           |
# |    time_elapsed         | 919         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009839467 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0368      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00375    |
# |    value_loss           | 0.0849      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 6           |
# |    time_elapsed         | 1147        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012729593 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0791      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 7           |
# |    time_elapsed         | 1365        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012952858 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0348      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 0.0856      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 8           |
# |    time_elapsed         | 1591        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008287492 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0631      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 9            |
# |    time_elapsed         | 1812         |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0056172293 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0658       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 0.0839       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 10         |
# |    time_elapsed         | 2040       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01434531 |
# |    clip_fraction        | 0.0935     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0241     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00658   |
# |    value_loss           | 0.0968     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 11           |
# |    time_elapsed         | 2288         |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0044024945 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0423       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000296    |
# |    value_loss           | 0.0853       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 12          |
# |    time_elapsed         | 2533        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016816473 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00755    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.0866      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 13          |
# |    time_elapsed         | 2777        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009738296 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0469      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 0.0867      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 14          |
# |    time_elapsed         | 3035        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008702323 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0338      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 0.0875      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 15           |
# |    time_elapsed         | 3290         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0021764576 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0439       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000656    |
# |    value_loss           | 0.0883       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 16           |
# |    time_elapsed         | 3560         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0030878605 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0189       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 0.0874       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 17           |
# |    time_elapsed         | 3857         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0057004564 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.031        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 0.0872       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 18          |
# |    time_elapsed         | 4213        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009295419 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0641      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 0.0888      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 19          |
# |    time_elapsed         | 4455        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005696304 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0565      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 0.0876      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 20          |
# |    time_elapsed         | 4694        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005666245 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0327      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 0.088       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 21          |
# |    time_elapsed         | 4927        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005605868 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0159      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00222    |
# |    value_loss           | 0.0877      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 22           |
# |    time_elapsed         | 5162         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0050690407 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0546       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 0.0875       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 23           |
# |    time_elapsed         | 5384         |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0053960523 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0684       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 0.0878       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 24           |
# |    time_elapsed         | 5615         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0038116183 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0593       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000934    |
# |    value_loss           | 0.0877       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 25           |
# |    time_elapsed         | 5854         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0057217544 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0149       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 0.0881       |
# ------------------------------------------

# %%
PPO_Path = os.path.join("Training", "Saved Models", "PPO_Model_Pong")
model.save(PPO_Path)

# %%
del model
model = PPO.load(PPO_Path, env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
evaluate_policy(model, env, n_eval_episodes=5, render=True)
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _  = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    
    print("Episode:{} Score:{}".format(episode, score))
env.close()
# Out:
# Episode:1 Score:[-21.]
# Episode:2 Score:[-21.]
# Episode:3 Score:[-21.]
# Episode:4 Score:[-21.]
# Episode:5 Score:[-21.]
